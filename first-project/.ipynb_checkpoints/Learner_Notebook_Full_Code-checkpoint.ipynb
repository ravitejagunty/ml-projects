# %% [markdown]
# # Project Python Foundations: FoodHub Data Analysis

# %% [markdown]
# ### Context
#
# The number of restaurants in New York is increasing day by day. Lots of students and busy professionals rely on those restaurants due to their hectic lifestyles. Online food delivery service is a great option for them. It provides them with good food from their favorite restaurants. A food aggregator company FoodHub offers access to multiple restaurants through a single smartphone app.
#
# The app allows the restaurants to receive a direct online order from a customer. The app assigns a delivery person from the company to pick up the order after it is confirmed by the restaurant. The delivery person then uses the map to reach the restaurant and waits for the food package. Once the food package is handed over to the delivery person, he/she confirms the pick-up in the app and travels to the customer's location to deliver the food. The delivery person confirms the drop-off in the app after delivering the food package to the customer. The customer can rate the order in the app. The food aggregator earns money by collecting a fixed margin of the delivery order from the restaurants.
#
# ### Objective
#
# The food aggregator company has stored the data of the different orders made by the registered customers in their online portal. They want to analyze the data to get a fair idea about the demand of different restaurants which will help them in enhancing their customer experience. Suppose you are hired as a Data Scientist in this company and the Data Science team has shared some of the key questions that need to be answered. Perform the data analysis to find answers to these questions that will help the company to improve the business.
#
# ### Data Description
#
# The data contains the different data related to a food order. The detailed data dictionary is given below.
#
# ### Data Dictionary
#
# * order_id: Unique ID of the order
# * customer_id: ID of the customer who ordered the food
# * restaurant_name: Name of the restaurant
# * cuisine_type: Cuisine ordered by the customer
# * cost_of_the_order: Cost of the order
# * day_of_the_week: Indicates whether the order is placed on a weekday or weekend (The weekday is from Monday to Friday and the weekend is Saturday and Sunday)
# * rating: Rating given by the customer out of 5
# * food_preparation_time: Time (in minutes) taken by the restaurant to prepare the food. This is calculated by taking the difference between the timestamps of the restaurant's order confirmation and the delivery person's pick-up confirmation.
# * delivery_time: Time (in minutes) taken by the delivery person to deliver the food package. This is calculated by taking the difference between the timestamps of the delivery person's pick-up confirmation and drop-off information

# %% [markdown]
# ### Let us start by importing the required libraries

# %%
# Installing the libraries with the specified version.
# !pip3 install numpy==1.25.2 pandas==1.5.3 matplotlib==3.7.1 seaborn==0.13.1 -q --user
# Out:
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [33 lines of output]
#       Traceback (most recent call last):
#         File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 112, in get_requires_for_build_wheel
#           backend = _build_backend()
#                     ^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# **Note**: *After running the above cell, kindly restart the notebook kernel and run all cells sequentially from the start again.*

# %%
# import libraries for data manipulation
import numpy as np
import pandas as pd

# import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Understanding the structure of the data

# %%
# uncomment and run the following lines for Google Colab
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# code for reading the data
data = pd.read_csv('/Users/ravs/Desktop/UTA-AIML/Projects/first-project/foodhub_order.csv')

# %%
# Write your code here to view the first 5 rows
data.head()
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time
# 0             20
# 1             23
# 2             28
# 3             15
# 4             24

# %% [markdown]
# ### **Question 1:** How many rows and columns are present in the data? [0.5 mark]

# %%
# Write your code here
print('Number of rows present in the data:',data.shape[0])
print('Number of columns present in the data:',data.shape[1])
# Out:
# Number of rows present in the data: 1898
# Number of columns present in the data: 9

# %% [markdown]
# #### Observations:
# The data have 1898 orders and 9 different columns that gives information about each order.

# %% [markdown]
# ### **Question 2:** What are the datatypes of the different columns in the dataset? (The info() function can be used) [0.5 mark]

# %%
# Write your code here
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1898 non-null   int64
#  1   customer_id            1898 non-null   int64
#  2   restaurant_name        1898 non-null   object
#  3   cuisine_type           1898 non-null   object
#  4   cost_of_the_order      1898 non-null   float64
#  5   day_of_the_week        1898 non-null   object
#  6   rating                 1898 non-null   object
#  7   food_preparation_time  1898 non-null   int64
#  8   delivery_time          1898 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 133.6+ KB

# %% [markdown]
# #### Observations:
# There are multiple datatypes in the give dataset with object(categorical) and int64 having 4 columns each.

# %% [markdown]
# ### **Question 3:** Are there any missing values in the data? If yes, treat them using an appropriate method. [1 mark]

# %%
# Write your code here
missing_values = data.isnull().sum()
if missing_values.sum() == 0:
    print('There are no missing values in the provided data')
else:
    print('There are', missing_values.sum(),'missing values in data')
# Out:
# There are no missing values in the provided data

# %% [markdown]
# #### Observations:
# It is observed that there are no missing values in the data set.

# %% [markdown]
# ### **Question 4:** Check the statistical summary of the data. What is the minimum, average, and maximum time it takes for food to be prepared once an order is placed? [2 marks]

# %%
# Write your code here
statistical_summary = data.describe()
print('Minumum time it takes to prepare food is', statistical_summary.loc['min','food_preparation_time'],'minutes')
print('Maximum time it takes to prepare food is', statistical_summary.loc['max','food_preparation_time'],'minutes')
print('Average time it takes to prepare food is', f"{statistical_summary.loc['mean','food_preparation_time']:.2f}",'minutes')
# Out:
# Minumum time it takes to prepare food is 20.0 minutes
# Maximum time it takes to prepare food is 35.0 minutes
# Average time it takes to prepare food is 27.37 minutes

# %% [markdown]
# #### Observations:
# The average time for food to be prepared is slightly closer to the minimum time taken to prepare the food with difference of 7.37 as opposed to 7.63 with maximum time.

# %% [markdown]
# ### **Question 5:** How many orders are not rated? [1 mark]

# %%
# Write the code here
# Cheking if there are any null values first
print('Amount of null values in the rating column', data['rating'].isnull().sum())
# Checking the see if there are any other unique values other than 'Not given' in the column
print('Deriving unique value(s) to identify not rated orders', data['rating'].unique())
# Extracting the data of Not given by condition
print('There are',data[data['rating'] == 'Not given'].shape[0],'orders that are not rated')
# Out:
# Amount of null values in the rating column 0
# Deriving unique value(s) to identify not rated orders ['Not given' '5' '3' '4']
# There are 736 orders that are not rated

# %% [markdown]
# #### Observations:
# There are 736 orders that are not rated, which could be concerning considering the total data set is just 1898 rows... If there were to perform analysis totally based on restaurant ratings this data might not provide accurate results considering we will have to either get rid of 736 rows which is about 39% of the data set or impute the values which is not accurate

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ### **Question 6:** Explore all the variables and provide observations on their distributions. (Generally, histograms, boxplots, countplots, etc. are used for univariate exploration.) [9 marks]

# %%
# Write the code here

# Distribution of `cost_of_the_order`
plt.figure(figsize=(10, 5))
sns.histplot(data['cost_of_the_order'], kde=True, bins=30, color='blue')
plt.title('Distribution of Order Costs')
plt.xlabel('Cost of the Order')
plt.ylabel('Frequency')
plt.show()

# Distribution of `food_preparation_time`
plt.figure(figsize=(10, 5))
sns.histplot(data['food_preparation_time'], kde=True, bins=30, color='blue')
plt.title('Distribution of Food preparation time')
plt.xlabel('Food preparation time')
plt.ylabel('Frequency')
plt.show()

# Distribution of `delivery_time`
plt.figure(figsize=(10, 5))
sns.histplot(data['delivery_time'], kde=True, bins=30, color='blue')
plt.title('Distribution of Delivery time')
plt.xlabel('Delivery time')
plt.ylabel('Frequency')
plt.show()


# Bar plot for `cuisine_type`
plt.figure(figsize=(10, 5))
sns.countplot(data=data, y='cuisine_type', order=data['cuisine_type'].value_counts().index)
plt.title('Frequency of Different Cuisines')
plt.xlabel('Count')
plt.ylabel('Cuisine Type')
plt.show()

# Count of orders by `day_of_the_week`
plt.figure(figsize=(10, 5))
sns.countplot(data=data, x='day_of_the_week', hue='day_of_the_week', legend=False)
plt.title('Orders by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Count')
plt.show()

#Box plot distribution of cost_of_the_order by day_of_the_week
plt.figure(figsize=(10, 5))
sns.boxplot(data=data, x='day_of_the_week', y='cost_of_the_order', legend=False)
plt.title('Order Costs by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Cost of the Order')
plt.show()

#Box plot distribution of delivery_time by cuisine_type
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='cuisine_type', y='delivery_time', legend=False)
plt.xticks(rotation=45)
plt.title('Delivery Time by Cuisine Type')
plt.xlabel('Cuisine Type')
plt.ylabel('Delivery Time (minutes)')
plt.show()

# %% [markdown]
# ### **Question 7**: Which are the top 5 restaurants in terms of the number of orders received? [1 mark]

# %%
# Write the code here
top_five_restaurants = data['restaurant_name'].value_counts().head(5)
print('Following are the top five restaruants that received most orders:')
print(top_five_restaurants)
# Out:
# Following are the top five restaruants that received most orders:
# restaurant_name
# Shake Shack                  219
# The Meatball Shop            132
# Blue Ribbon Sushi            119
# Blue Ribbon Fried Chicken     96
# Parm                          68
# Name: count, dtype: int64

# %% [markdown]
# #### Observations:
# Combination of two american restaurants 'Shake Shack' and  'Blue Ribbon Fried Chicken' orders - 315 in total is very close to rest of cuisines order together which is 319 (which is split between Italian and Japanese).
# American cuisine is seeing more orders than other types of cuisines in top 5 restaurants.

# %% [markdown]
# ### **Question 8**: Which is the most popular cuisine on weekends? [1 mark]

# %%
# Write the code here
weekend_restaurants = data[data['day_of_the_week'] == 'Weekend']
popular_weekend_cuisine = weekend_restaurants['cuisine_type'].value_counts().head(1)
print('The most popular cuisine on weekends is',popular_weekend_cuisine.index[0], 'with', popular_weekend_cuisine.iloc[0], 'orders')
# Out:
# The most popular cuisine on weekends is American with 415 orders

# %% [markdown]
# #### Observations:
# The most popular cuisine on weekends is American with 415 orders

# %% [markdown]
# ### **Question 9**: What percentage of the orders cost more than 20 dollars? [2 marks]

# %%
# Write the code here
order_above_twenty_dollars = len(data[data['cost_of_the_order'] > 20])
order_percentage = (order_above_twenty_dollars/len(data)) * 100
print(f"Percentage of orders that cost more than 20 dollars: {order_percentage:.2f}%")
# Out:
# Percentage of orders that cost more than 20 dollars: 29.24%

# %% [markdown]
# #### Observations:
# 1. More than 70% of customers are spending less than or equal to 20 dollars to order food.

# %% [markdown]
# ### **Question 10**: What is the mean order delivery time? [1 mark]

# %%
# Write the code here
#leveraging the 'statistical_summary' derived previousy to execute mean value for delivery_time
print('Average time it takes to delivery food is', f"{statistical_summary.loc['mean','delivery_time']:.2f}",'minutes')
# Out:
# Average time it takes to delivery food is 24.16 minutes

# %% [markdown]
# #### Observations:
# It takes on average 24 minutes and 16 seconds to deliver food, this in relation to average food prepare time can provide a good insights of what is the average time it takes for a user to place and order and receive it.

# %% [markdown]
# ### **Question 11:** The company has decided to give 20% discount vouchers to the top 3 most frequent customers. Find the IDs of these customers and the number of orders they placed. [1 mark]

# %%
# Write the code here
top_three_customers = data['customer_id'].value_counts().head(3)
for i in range(len(top_three_customers)):
    print(f"The top {i+1} customer with ID: {top_three_customers.index[i]} has placed {top_three_customers.iloc[i]} orders.")
# Out:
# The top 1 customer with ID: 52832 has placed 13 orders.
# The top 2 customer with ID: 47440 has placed 10 orders.
# The top 3 customer with ID: 83287 has placed 9 orders.

# %% [markdown]
# #### Observations:
# The maximum number of orders placed by a single customer in the given data set is 13 orders.

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# ### **Question 12**: Perform a multivariate analysis to explore relationships between the important variables in the dataset. (It is a good idea to explore relations between numerical variables as well as relations between numerical and categorical variables) [10 marks]

# %%
# Write the code here
# Correlation heatmap for numerical variables
plt.figure(figsize=(10, 6))
correlation_matrix = data[['cost_of_the_order', 'food_preparation_time', 'delivery_time']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap for Numerical Variables')
plt.show()

# Scatter plot: Cost of the order vs Rating, categorized by day_of_the_week
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='cost_of_the_order', y='rating', hue='day_of_the_week', legend=True)
plt.title('Cost of the Order vs Rating by Day of the Week')
plt.xlabel('Cost of the Order')
plt.ylabel('Rating')
plt.legend(title='Day of the Week')
plt.show()

# Boxplot: Delivery time by Cuisine Type
plt.figure(figsize=(14, 7))
sns.boxplot(data=data, x='cuisine_type', y='delivery_time', legend=False)
plt.title('Delivery Time by Cuisine Type')
plt.xlabel('Cuisine Type')
plt.ylabel('Delivery Time (minutes)')
plt.xticks(rotation=45)
plt.show()

# Pairplot for numerical variables to explore all pairwise relationships
sns.pairplot(data[['cost_of_the_order', 'food_preparation_time', 'delivery_time']])
plt.show()

#Filtering out the rows with no rating to perform the analysis on that data.
data_with_ratings = data[data['rating'] != 'Not given']

# Correlation heatmap for numerical variables
plt.figure(figsize=(10, 6))
correlation_matrix = data_with_ratings[['cost_of_the_order', 'food_preparation_time', 'delivery_time', 'rating']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap for Numerical Variables')
plt.show()

# Pairplot for numerical variables to explore all pairwise relationships
data_with_ratings.loc[:,'rating'] = data_with_ratings['rating'].astype(int)
sns.pairplot(data_with_ratings[['cost_of_the_order', 'food_preparation_time', 'delivery_time', 'rating']])
plt.show()

# %% [markdown]
# ### **Question 13:** The company wants to provide a promotional offer in the advertisement of the restaurants. The condition to get the offer is that the restaurants must have a rating count of more than 50 and the average rating should be greater than 4. Find the restaurants fulfilling the criteria to get the promotional offer. [3 marks]

# %%
# Write the code here
# use the new data set data_with_ratings group the restaurant_name to calculate rating count and average rating
restaurant_stats_by_rating = data_with_ratings.groupby('restaurant_name')['rating'].agg(['count', 'mean'])
# filter the restaurants that have count of more than 50 and average rating greater than 4
promo_eligible_restaurants = restaurant_stats_by_rating[(restaurant_stats_by_rating['count'] > 50) & (restaurant_stats_by_rating['mean'] > 4.0)]
# Resetting index to display print statements of all eligible restaurants
promo_eligible_restaurants.reset_index(inplace=True)
for index, row in promo_eligible_restaurants.iterrows():
    print(
        f"Restaurant '{row['restaurant_name']}' qualifies for the promotional offer "
        f"with a rating count of {int(row['count'])} and an average rating of {row['mean']:.2f}."
    )
# Out:
# Restaurant 'Blue Ribbon Fried Chicken' qualifies for the promotional offer with a rating count of 64 and an average rating of 4.33.
# Restaurant 'Blue Ribbon Sushi' qualifies for the promotional offer with a rating count of 73 and an average rating of 4.22.
# Restaurant 'Shake Shack' qualifies for the promotional offer with a rating count of 133 and an average rating of 4.28.
# Restaurant 'The Meatball Shop' qualifies for the promotional offer with a rating count of 84 and an average rating of 4.51.

# %% [markdown]
# #### Observations:
# Restaurant 'Blue Ribbon Fried Chicken' qualifies for the promotional offer with a rating count of 64 and an average rating of 4.33.
#
# Restaurant 'Blue Ribbon Sushi' qualifies for the promotional offer with a rating count of 73 and an average rating of 4.22.
#
# Restaurant 'Shake Shack' qualifies for the promotional offer with a rating count of 133 and an average rating of 4.28.
#
# Restaurant 'The Meatball Shop' qualifies for the promotional offer with a rating count of 84 and an average rating of 4.51.

# %% [markdown]
# ### **Question 14:** The company charges the restaurant 25% on the orders having cost greater than 20 dollars and 15% on the orders having cost greater than 5 dollars. Find the net revenue generated by the company across all orders. [3 marks]

# %%
# Write the code here
# Define a function to calculate the commission based on order cost
def calculate_commission(cost):
    if cost > 20:
        return cost * 0.25
    elif cost > 5:
        return cost * 0.15
    else:
        return 0

# function to calculate commission for each order
data['commission'] = data['cost_of_the_order'].apply(calculate_commission)

# Calculating the total revenue generated
total_revenue = data['commission'].sum()
print(f"Total Revenue Generated: ${total_revenue:.2f}")
# Out:
# Total Revenue Generated: $6166.30

# %% [markdown]
# #### Observations:
# The total revenue generated by the company is $6166.30

# %% [markdown]
# ### **Question 15:** The company wants to analyze the total time required to deliver the food. What percentage of orders take more than 60 minutes to get delivered from the time the order is placed? (The food has to be prepared and then delivered.) [2 marks]

# %%
# Write the code here
# Calculate the total time required for each order (food preparation time + delivery time)
data['total_time'] = data['food_preparation_time'] + data['delivery_time']

# Calculate the number of orders that take more than 60 minutes
orders_above_60 = data[data['total_time'] > 60].shape[0]

# Calculate the total number of orders
total_orders = data.shape[0]

# Calculate the percentage of orders taking more than 60 minutes
percentage_above_60 = (orders_above_60 / total_orders) * 100

# Display the result
print(f"Percentage of orders taking more than 60 minutes: {percentage_above_60:.2f}%")
# Out:
# Percentage of orders taking more than 60 minutes: 10.54%

# %% [markdown]
# #### Observations:
# 10.54% of restaurants take more than 60 minutes to deliver the food.

# %% [markdown]
# ### **Question 16:** The company wants to analyze the delivery time of the orders on weekdays and weekends. How does the mean delivery time vary during weekdays and weekends? [2 marks]

# %%
# Write the code here
# Calculate the mean delivery time for weekdays and weekends
mean_delivery_time = data.groupby('day_of_the_week')['delivery_time'].mean()

# Display the mean delivery times
print("Mean Delivery Time:")
for day_type, mean_time in mean_delivery_time.items():
    print(f"{day_type}: {mean_time:.2f} minutes")
# Out:
# Mean Delivery Time:
# Weekday: 28.34 minutes
# Weekend: 22.47 minutes

# %% [markdown]
# #### Observations:

# %% [markdown]
# ### Conclusion and Recommendations

# %% [markdown]
# ### **Question 17:** What are your conclusions from the analysis? What recommendations would you like to share to help improve the business? (You can use cuisine type and feedback ratings to drive your business recommendations.) [6 marks]

# %% [markdown]
# ### Conclusions:
# Ratings Missing:
#
# About 38.78% of the orders do not have ratings provided. This is a significant gap in customer feedback.
# Cuisine Popularity:
#
# The most popular cuisine is American, followed by Japanese, Italian, and Chinese.
# Mexican cuisine is among the top five but has relatively lower popularity.
# Order Costs:
#
# Average order costs are relatively consistent across cuisines, with the highest costs observed for Southern, Spanish, and Thai cuisines.
# Delivery Time by Cuisine:
#
# Vietnamese cuisine has the longest average delivery time (26.14 minutes), while Korean cuisine is delivered the fastest (20.92 minutes on average).
# Weekday vs. Weekend:
#
# Weekend orders are far more frequent (71.18% of total orders) and have a shorter average delivery time (22.47 minutes) compared to weekdays (28.34 minutes).
# Long Delivery Times:
#
# About 10.54% of the orders take more than 60 minutes for food preparation and delivery combined.
# Restaurant Popularity:
#
# The most popular restaurant is Shake Shack, while the least popular is Le Zie 2000 Trattoria.
# Preparation Time:
#
# The mean food preparation time is 27.37 minutes, which is a significant contributor to overall delivery time.

# %% [markdown]
# ### Recommendations:
#
# Encourage Customer Feedback:
#
# Implement a system to encourage customers to rate their orders, possibly through discounts or loyalty points, to fill the feedback gap.
# Optimize Delivery for Weekdays:
#
# Focus on improving delivery times on weekdays to match weekend efficiency. This may involve revisiting staffing and delivery logistics.
# Improve Efficiency for Longer Deliveries:
#
# Analyze orders that take more than 60 minutes to identify bottlenecks (e.g., restaurant prep times, delivery routing).
# Tailor Offerings by Cuisine:
#
# Highlight and promote faster cuisines like Korean during peak hours to attract customers who prioritize speed.
# Focus on Popular Restaurants:
#
# Partner closely with popular restaurants like Shake Shack to streamline operations and ensure customer satisfaction.
# Support less popular restaurants with marketing and logistical advice to boost their order volume.
# Promote Weekend Orders:
#
# Offer special deals or discounts during weekends to leverage the already higher volume of orders.
# Optimize Preparation Times:
#
# Work with restaurants to streamline preparation processes, especially for cuisines with longer times like Vietnamese.

# %% [markdown]
# ---
